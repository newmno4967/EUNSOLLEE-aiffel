# %% [markdown]
# <a href="https://colab.research.google.com/github/nbche/AIFFEL_quest_cr/blob/main/m3_03Dec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# --------------M3 최종 결과물 (양건우)

# %%
def check_palindrome():  ## 회문 함수 작성
    x = list(input())    ## 단어 입력
    print(x)             ## 단어 출력

    y = x[::-1]           ## 회문 생성
    print(y)              ## 회문 출력

    if x == y:              ## 회문 여부 파악 if 문
        print("회문입니다.")
    else:
        print("회문이 아닙니다.")

check_palindrome()

# %% [markdown]
# ------ Test A (박종호)

# %%
#앞으로 읽어도 우영우 꺼꾸로 읽어도 우영우
##입력받은 문자를 거꾸로 돌려서 원래 입력받은 문자랑 같은지를 확인
###글자를 얼마나 입력받을지 모르니 args함수를 써야겠지?


origin = list(input("글자를 입력하세요:"))

def reversed_text(*args):
    '''이 함수는 입력받은 리스트 순서를 거꾸로 돌린후 비교하는 함수'''
    compare = list(reversed(origin))
    if origin == compare :
        print(origin,"회귀함수? : True")
    else :
        print(origin,"회귀함수? : False")

reversed_text(*origin)

# %% [markdown]
# -------- Test B (채남병)

# %%
x = list(input("단어를 입력해 주십시오."))  ## 단어 입력하기
print(x)
type(x)
len(x)
# Out:
# 단어를 입력해 주십시오.우리나라
# ['우', '리', '나', '라']
# 4

# %%
def palindrome():
  for i in range(-len(x):-1):
      print(i, end='')
# Out:
#   File "<ipython-input-40-8ccfa4aad8b8>", line 2
#     for i in range(-1:-len(x)):
#                      ^
# SyntaxError: invalid syntax

# %%
x = list(input("단어 입력 "))
print(x[i], end ="")
for i in range(-len(x),-1):
  print (i, end='')
# Out:
# 단어 입력 우리나라
# 나-4-3-2

# %%
if x == y:
  print ("회문입니다.")
else:
  print ("회문이 아닙니다.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-97e73628b08b> in <cell line: 1>()
# ----> 1 if x == y:
#       2   print ("회문입니다.")
#       3 else:
#       4   print ("회문이 아닙니다.")
#
# NameError: name 'y' is not defined

# %% [markdown]
# ------
